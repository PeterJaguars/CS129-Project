# %%
pip install torch torchvision torchaudio
# Out:
# Requirement already satisfied: torch in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (1.8.0)
# Requirement already satisfied: torchvision in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (0.9.0)
# Requirement already satisfied: torchaudio in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (0.8.0)
# Requirement already satisfied: typing-extensions in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from torch) (3.7.4.3)
# Requirement already satisfied: numpy in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from torch) (1.19.2)
# Requirement already satisfied: pillow>=4.1.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from torchvision) (8.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install keras
# Out:
# Requirement already satisfied: keras in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (2.4.3)
# Requirement already satisfied: h5py in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from keras) (1.19.2)
# Requirement already satisfied: scipy>=0.14 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from keras) (1.5.2)
# Requirement already satisfied: pyyaml in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from keras) (5.3.1)
# Requirement already satisfied: six in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from h5py->keras) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (2.4.1)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: tensorboard~=2.4 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.1)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: wheel~=0.35 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.35.1)
# Requirement already satisfied: h5py~=2.10.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.10.0)
# Requirement already satisfied: google-pasta~=0.2 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.3.3)
# Requirement already satisfied: numpy~=1.19.2 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.2)
# Requirement already satisfied: grpcio~=1.32.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.32.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.15.6)
# Requirement already satisfied: tensorflow-estimator<2.5.0,>=2.4.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (2.4.0)
# Requirement already satisfied: absl-py~=0.10 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: six~=1.15.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (0.4.3)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.0.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.8.0)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (2.24.0)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (50.3.1.post20201107)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (1.28.0)
# Requirement already satisfied: markdown>=2.6.8 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.4->tensorflow) (3.3.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow) (1.25.11)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (4.2.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /Users/quinnsmalling1/opt/anaconda3/lib/python3.8/site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard~=2.4->tensorflow) (0.4.8)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn
import numpy as np
import pandas as pd
data = pd.read_csv('NFL-PBPDataCleanedUpdate.csv')
pd.set_option('display.max_columns', None)
data = data.drop(columns=['Unnamed: 0', 'game_id', 'desc', 'qb_scramble', 'qb_dropback','air_yards', 'roof', 'run_gap'])

import torch
import os
import numpy as np
from tqdm import tqdm
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from torch import nn, optim
import torch.nn.functional as F


import tensorflow as tf
from tensorflow import keras
from keras import optimizers
from keras.utils import to_categorical
from keras.models import Model
from keras.models import Sequential
from keras.regularizers import l2
from keras.layers import Conv2D, Input, ZeroPadding1D, MaxPooling2D, BatchNormalization, Activation, Dropout, Flatten, Dense


from keras.wrappers.scikit_learn import KerasClassifier
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
torch.manual_seed(RANDOM_SEED)


data
# Out:
#         down  ydstogo  yardline_100  score_differential  \
# 0          1       10            77                   0
# 1          2       13            80                   0
# 2          3        6            73                   0
# 3          1       10            50                   0
# 4          2       10            50                   0
# ...      ...      ...           ...                 ...
# 322460     3        4            86                  -6
# 322461     4        4            86                  -6
# 322462     1       10            74                  -6
# 322463     2       10            74                  -6
# 322464     3       10            74                  -6
#
#         game_seconds_remaining play_type  shotgun  no_huddle pass_length  \
# 0                         3590       run        0          0         NaN
# 1                         3557      pass        0          0       short
# 2                         3517      pass        0          0        deep
# 3                         3491       run        0          0         NaN
# 4                         3453      pass        0          0        deep
# ...                        ...       ...      ...        ...         ...
# 322460                      44      pass        1          0       short
# 322461                      38       run        1          0         NaN
# 322462                      16      pass        1          1        deep
# 322463                      11      pass        1          0       short
# 322464                       6      pass        1          0       short
#
#        pass_location run_location posteam_type  half_seconds_remaining  \
# 0                NaN         left         home                    1790
# 1              right          NaN         home                    1757
# 2               left          NaN         home                    1717
# 3                NaN         left         home                    1691
# 4              right          NaN         home                    1653
# ...              ...          ...          ...                     ...
# 322460          left          NaN         home                      44
# 322461           NaN       middle         home                      38
# 322462         right          NaN         home                      16
# 322463          left          NaN         home                      11
# 322464        middle          NaN         home                       6
#
#         yards_gained  posteam_timeouts_remaining  defteam_timeouts_remaining  \
# 0                 -3                           3                           3
# 1                  7                           3                           3
# 2                 23                           3                           3
# 3                  0                           3                           3
# 4                  0                           3                           3
# ...              ...                         ...                         ...
# 322460             0                           0                           1
# 322461            12                           0                           1
# 322462             0                           0                           1
# 322463             0                           0                           1
# 322464             6                           0                           1
#
#         posteam_score  defteam_score        wp  vegas_wp  spread_line  \
# 0                   0              0  0.546969  0.460187         -1.0
# 1                   0              0  0.520599  0.400522         -1.0
# 2                   0              0  0.512282  0.417211         -1.0
# 3                   0              0  0.584447  0.490365         -1.0
# 4                   0              0  0.566532  0.460875         -1.0
# ...               ...            ...       ...       ...          ...
# 322460             14             20  0.065262  0.037043         -6.5
# 322461             14             20  0.046147  0.022904         -6.5
# 322462             14             20  0.044689  0.023246         -6.5
# 322463             14             20  0.033163  0.016259         -6.5
# 322464             14             20  0.034751  0.011474         -6.5
#
#         total_line surface  temp  wind     xpass
# 0             40.5   grass  76.0   7.0  0.441336
# 1             40.5   grass  76.0   7.0  0.606305
# 2             40.5   grass  76.0   7.0  0.972548
# 3             40.5   grass  76.0   7.0  0.443912
# 4             40.5   grass  76.0   7.0  0.485260
# ...            ...     ...   ...   ...       ...
# 322460        43.5   grass  38.0  10.0  0.986473
# 322461        43.5   grass  38.0  10.0  0.993961
# 322462        43.5   grass  38.0  10.0  0.990118
# 322463        43.5   grass  38.0  10.0  0.992962
# 322464        43.5   grass  38.0  10.0  0.984498
#
# [322465 rows x 26 columns]

# %%
data = data.drop(columns=['pass_length', 'pass_location', 'run_location'])

# %%
data = data.drop(columns=['yards_gained'])
data = data.dropna()
y = data.pop('play_type')
data
# Out:
#         down  ydstogo  yardline_100  score_differential  \
# 0          1       10            77                   0
# 1          2       13            80                   0
# 2          3        6            73                   0
# 3          1       10            50                   0
# 4          2       10            50                   0
# ...      ...      ...           ...                 ...
# 322460     3        4            86                  -6
# 322461     4        4            86                  -6
# 322462     1       10            74                  -6
# 322463     2       10            74                  -6
# 322464     3       10            74                  -6
#
#         game_seconds_remaining  shotgun  no_huddle posteam_type  \
# 0                         3590        0          0         home
# 1                         3557        0          0         home
# 2                         3517        0          0         home
# 3                         3491        0          0         home
# 4                         3453        0          0         home
# ...                        ...      ...        ...          ...
# 322460                      44        1          0         home
# 322461                      38        1          0         home
# 322462                      16        1          1         home
# 322463                      11        1          0         home
# 322464                       6        1          0         home
#
#         half_seconds_remaining  posteam_timeouts_remaining  \
# 0                         1790                           3
# 1                         1757                           3
# 2                         1717                           3
# 3                         1691                           3
# 4                         1653                           3
# ...                        ...                         ...
# 322460                      44                           0
# 322461                      38                           0
# 322462                      16                           0
# 322463                      11                           0
# 322464                       6                           0
#
#         defteam_timeouts_remaining  posteam_score  defteam_score        wp  \
# 0                                3              0              0  0.546969
# 1                                3              0              0  0.520599
# 2                                3              0              0  0.512282
# 3                                3              0              0  0.584447
# 4                                3              0              0  0.566532
# ...                            ...            ...            ...       ...
# 322460                           1             14             20  0.065262
# 322461                           1             14             20  0.046147
# 322462                           1             14             20  0.044689
# 322463                           1             14             20  0.033163
# 322464                           1             14             20  0.034751
#
#         vegas_wp  spread_line  total_line surface  temp  wind     xpass
# 0       0.460187         -1.0        40.5   grass  76.0   7.0  0.441336
# 1       0.400522         -1.0        40.5   grass  76.0   7.0  0.606305
# 2       0.417211         -1.0        40.5   grass  76.0   7.0  0.972548
# 3       0.490365         -1.0        40.5   grass  76.0   7.0  0.443912
# 4       0.460875         -1.0        40.5   grass  76.0   7.0  0.485260
# ...          ...          ...         ...     ...   ...   ...       ...
# 322460  0.037043         -6.5        43.5   grass  38.0  10.0  0.986473
# 322461  0.022904         -6.5        43.5   grass  38.0  10.0  0.993961
# 322462  0.023246         -6.5        43.5   grass  38.0  10.0  0.990118
# 322463  0.016259         -6.5        43.5   grass  38.0  10.0  0.992962
# 322464  0.011474         -6.5        43.5   grass  38.0  10.0  0.984498
#
# [233184 rows x 21 columns]

# %%
def play_to_bin(col):
    newcol = []
    for val in col:
        if val == 'run':
             newcol.append(0);
        else:
            newcol.append(1);
    
    return newcol

# %%
y = play_to_bin(y)
y = np.array(y)

# %%
def posteam_type_to_bin(col):
    newcol = []
    for val in col:
        if val == 'home':
             newcol.append(0);
        else:
            newcol.append(1);
    
    return newcol

# %%
def surface_to_bin(col):
    newcol = []
    for val in col:
        if val == 'grass':
            newcol.append(0);
        else:
            newcol.append(1);
    
    return newcol

# %%
data['posteam_type'] = posteam_type_to_bin(data['posteam_type'])
data['surface'] = surface_to_bin(data['surface'])
data
# Out:
#         down  ydstogo  yardline_100  score_differential  \
# 0          1       10            77                   0
# 1          2       13            80                   0
# 2          3        6            73                   0
# 3          1       10            50                   0
# 4          2       10            50                   0
# ...      ...      ...           ...                 ...
# 322460     3        4            86                  -6
# 322461     4        4            86                  -6
# 322462     1       10            74                  -6
# 322463     2       10            74                  -6
# 322464     3       10            74                  -6
#
#         game_seconds_remaining  shotgun  no_huddle  posteam_type  \
# 0                         3590        0          0             0
# 1                         3557        0          0             0
# 2                         3517        0          0             0
# 3                         3491        0          0             0
# 4                         3453        0          0             0
# ...                        ...      ...        ...           ...
# 322460                      44        1          0             0
# 322461                      38        1          0             0
# 322462                      16        1          1             0
# 322463                      11        1          0             0
# 322464                       6        1          0             0
#
#         half_seconds_remaining  posteam_timeouts_remaining  \
# 0                         1790                           3
# 1                         1757                           3
# 2                         1717                           3
# 3                         1691                           3
# 4                         1653                           3
# ...                        ...                         ...
# 322460                      44                           0
# 322461                      38                           0
# 322462                      16                           0
# 322463                      11                           0
# 322464                       6                           0
#
#         defteam_timeouts_remaining  posteam_score  defteam_score        wp  \
# 0                                3              0              0  0.546969
# 1                                3              0              0  0.520599
# 2                                3              0              0  0.512282
# 3                                3              0              0  0.584447
# 4                                3              0              0  0.566532
# ...                            ...            ...            ...       ...
# 322460                           1             14             20  0.065262
# 322461                           1             14             20  0.046147
# 322462                           1             14             20  0.044689
# 322463                           1             14             20  0.033163
# 322464                           1             14             20  0.034751
#
#         vegas_wp  spread_line  total_line  surface  temp  wind     xpass
# 0       0.460187         -1.0        40.5        0  76.0   7.0  0.441336
# 1       0.400522         -1.0        40.5        0  76.0   7.0  0.606305
# 2       0.417211         -1.0        40.5        0  76.0   7.0  0.972548
# 3       0.490365         -1.0        40.5        0  76.0   7.0  0.443912
# 4       0.460875         -1.0        40.5        0  76.0   7.0  0.485260
# ...          ...          ...         ...      ...   ...   ...       ...
# 322460  0.037043         -6.5        43.5        0  38.0  10.0  0.986473
# 322461  0.022904         -6.5        43.5        0  38.0  10.0  0.993961
# 322462  0.023246         -6.5        43.5        0  38.0  10.0  0.990118
# 322463  0.016259         -6.5        43.5        0  38.0  10.0  0.992962
# 322464  0.011474         -6.5        43.5        0  38.0  10.0  0.984498
#
# [233184 rows x 21 columns]

# %%
for col in data:
    data[col] = (data[col] - pd.DataFrame.mean(data[col]))/(pd.DataFrame.max(data[col]) - pd.DataFrame.min(data[col]))

# %%
data
# Out:
#             down   ydstogo  yardline_100  score_differential  \
# 0      -0.265105  0.027795      0.251373            0.013437
# 1       0.068228  0.089019      0.281985            0.013437
# 2       0.401561 -0.053838      0.210556            0.013437
# 3      -0.265105  0.027795     -0.024137            0.013437
# 4       0.068228  0.027795     -0.024137            0.013437
# ...          ...       ...           ...                 ...
# 322460  0.401561 -0.094654      0.343209           -0.039661
# 322461  0.734895 -0.094654      0.343209           -0.039661
# 322462 -0.265105  0.027795      0.220760           -0.039661
# 322463  0.068228  0.027795      0.220760           -0.039661
# 322464  0.401561  0.027795      0.220760           -0.039661
#
#         game_seconds_remaining   shotgun  no_huddle  posteam_type  \
# 0                     0.512641 -0.596104   -0.10532     -0.501188
# 1                     0.503474 -0.596104   -0.10532     -0.501188
# 2                     0.492363 -0.596104   -0.10532     -0.501188
# 3                     0.485141 -0.596104   -0.10532     -0.501188
# 4                     0.474585 -0.596104   -0.10532     -0.501188
# ...                        ...       ...        ...           ...
# 322460               -0.472359  0.403896   -0.10532     -0.501188
# 322461               -0.474026  0.403896   -0.10532     -0.501188
# 322462               -0.480137  0.403896    0.89468     -0.501188
# 322463               -0.481526  0.403896   -0.10532     -0.501188
# 322464               -0.482915  0.403896   -0.10532     -0.501188
#
#         half_seconds_remaining  posteam_timeouts_remaining  \
# 0                     0.521722                    0.143124
# 1                     0.503388                    0.143124
# 2                     0.481166                    0.143124
# 3                     0.466722                    0.143124
# 4                     0.445611                    0.143124
# ...                        ...                         ...
# 322460               -0.448278                   -0.856876
# 322461               -0.451612                   -0.856876
# 322462               -0.463834                   -0.856876
# 322463               -0.466612                   -0.856876
# 322464               -0.469389                   -0.856876
#
#         defteam_timeouts_remaining  posteam_score  defteam_score        wp  \
# 0                         0.133870      -0.170878      -0.196612  0.045348
# 1                         0.133870      -0.170878      -0.196612  0.018976
# 2                         0.133870      -0.170878      -0.196612  0.010658
# 3                         0.133870      -0.170878      -0.196612  0.082827
# 4                         0.133870      -0.170878      -0.196612  0.064911
# ...                            ...            ...            ...       ...
# 322460                   -0.532797       0.066410       0.142371 -0.436388
# 322461                   -0.532797       0.066410       0.142371 -0.455504
# 322462                   -0.532797       0.066410       0.142371 -0.456961
# 322463                   -0.532797       0.066410       0.142371 -0.468488
# 322464                   -0.532797       0.066410       0.142371 -0.466900
#
#         vegas_wp  spread_line  total_line   surface      temp      wind  \
# 0      -0.041665    -0.066188   -0.146641 -0.280071  0.174517 -0.016768
# 1      -0.101331    -0.066188   -0.146641 -0.280071  0.174517 -0.016768
# 2      -0.084642    -0.066188   -0.146641 -0.280071  0.174517 -0.016768
# 3      -0.011487    -0.066188   -0.146641 -0.280071  0.174517 -0.016768
# 4      -0.040977    -0.066188   -0.146641 -0.280071  0.174517 -0.016768
# ...          ...          ...         ...       ...       ...       ...
# 322460 -0.464812    -0.188410   -0.048280 -0.280071 -0.221317  0.025485
# 322461 -0.478951    -0.188410   -0.048280 -0.280071 -0.221317  0.025485
# 322462 -0.478609    -0.188410   -0.048280 -0.280071 -0.221317  0.025485
# 322463 -0.485596    -0.188410   -0.048280 -0.280071 -0.221317  0.025485
# 322464 -0.490381    -0.188410   -0.048280 -0.280071 -0.221317  0.025485
#
#            xpass
# 0      -0.173510
# 1      -0.006450
# 2       0.364438
# 3      -0.170901
# 4      -0.129030
# ...          ...
# 322460  0.378539
# 322461  0.386122
# 322462  0.382231
# 322463  0.385110
# 322464  0.376539
#
# [233184 rows x 21 columns]

# %%
for col in X_run:
    X_run[col] = (X_run[col] - pd.DataFrame.mean(X_run[col]))/(pd.DataFrame.max(X_run[col]) - pd.DataFrame.min(X_run[col]))
    
X_run
# Out:
#             down   ydstogo  yardline_100  score_differential  \
# 0      -0.194766  0.040142      0.259482           -0.004922
# 3      -0.194766  0.040142     -0.016028           -0.004922
# 7       0.138568 -0.026525     -0.281334           -0.004922
# 9      -0.194766  0.040142      0.290094           -0.032195
# 11     -0.194766  0.040142      0.147237           -0.032195
# ...          ...       ...           ...                 ...
# 322454  0.471901  0.040142      0.086013            0.049623
# 322455 -0.194766  0.040142     -0.067048            0.049623
# 322456  0.138568 -0.070969     -0.118069            0.049623
# 322457  0.471901 -0.093192     -0.128273            0.049623
# 322461  0.805234 -0.093192      0.351319           -0.059468
#
#         game_seconds_remaining   shotgun  no_huddle  posteam_type  \
# 0                     0.496136 -0.357106  -0.082036           NaN
# 3                     0.468636 -0.357106  -0.082036           NaN
# 7                     0.433080 -0.357106  -0.082036           NaN
# 9                     0.415025 -0.357106  -0.082036           NaN
# 11                    0.397525 -0.357106   0.917964           NaN
# ...                        ...       ...        ...           ...
# 322454               -0.465253 -0.357106  -0.082036           NaN
# 322455               -0.467753 -0.357106  -0.082036           NaN
# 322456               -0.469142 -0.357106  -0.082036           NaN
# 322457               -0.470808 -0.357106  -0.082036           NaN
# 322461               -0.490531  0.642894  -0.082036           NaN
#
#         half_seconds_remaining  yards_gained  posteam_timeouts_remaining  \
# 0                     0.489321     -0.064030                    0.116236
# 3                     0.434321     -0.038168                    0.116236
# 7                     0.363210     -0.072651                    0.116236
# 9                     0.327099     -0.012306                    0.116236
# 11                    0.292099      0.039418                    0.116236
# ...                        ...           ...                         ...
# 322454               -0.433457      0.039418                   -0.217097
# 322455               -0.438457      0.004935                   -0.217097
# 322456               -0.441234     -0.029547                   -0.217097
# 322457               -0.444568     -0.012306                   -0.217097
# 322461               -0.484012      0.065280                   -0.883764
#
#         defteam_timeouts_remaining  posteam_score  defteam_score        wp  \
# 0                         0.122719      -0.181561      -0.172384 -0.024106
# 3                         0.122719      -0.181561      -0.172384  0.013374
# 7                         0.122719      -0.181561      -0.172384  0.068442
# 9                         0.122719      -0.181561      -0.121537 -0.173505
# 11                        0.122719      -0.181561      -0.121537 -0.141487
# ...                            ...            ...            ...       ...
# 322454                   -0.210614       0.157422       0.064904  0.371215
# 322455                   -0.210614       0.157422       0.064904  0.405500
# 322456                   -0.543948       0.157422       0.064904  0.402935
# 322457                   -0.877281       0.157422       0.064904  0.402641
# 322461                   -0.543948       0.055727       0.166599 -0.524957
#
#         vegas_wp  spread_line  total_line  surface      temp      wind  \
# 0      -0.108099    -0.066624   -0.141679      NaN  0.176673 -0.017348
# 3      -0.077921    -0.066624   -0.141679      NaN  0.176673 -0.017348
# 7      -0.039365    -0.066624   -0.141679      NaN  0.176673 -0.017348
# 9      -0.065324    -0.066624   -0.141679      NaN  0.176673 -0.017348
# 11     -0.037612    -0.066624   -0.141679      NaN  0.176673 -0.017348
# ...          ...          ...         ...      ...       ...       ...
# 322454  0.388128    -0.188846   -0.043318      NaN -0.219160  0.024906
# 322455  0.417479    -0.188846   -0.043318      NaN -0.219160  0.024906
# 322456  0.418407    -0.188846   -0.043318      NaN -0.219160  0.024906
# 322457  0.419580    -0.188846   -0.043318      NaN -0.219160  0.024906
# 322461 -0.545384    -0.188846   -0.043318      NaN -0.219160  0.024906
#
#            xpass
# 0      -0.032990
# 3      -0.030374
# 7       0.124097
# 9       0.004322
# 11      0.012516
# ...          ...
# 322454  0.350003
# 322455 -0.431140
# 322456 -0.400678
# 322457 -0.301368
# 322461  0.528118
#
# [95739 rows x 22 columns]

# %%
X = data
y = to_categorical(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
print(X_train.shape)
# Out:
# (186547, 21)

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(21,)),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(128, kernel_regularizer=l2(0.1), activation=tf.nn.relu),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(64, activation=tf.nn.relu),
    keras.layers.Dense(2, activation=tf.nn.sigmoid),
])

adam = optimizers.Adam(lr = 0.005)

model.compile(optimizer=adam,
              loss='binary_crossentropy',
              metrics=['accuracy'])

history = model.fit(X_train, y_train, epochs=50, batch_size=128,
                    validation_data = (X_test, y_test))

test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# Epoch 1/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.8770 - accuracy: 0.7205 - val_loss: 0.5385 - val_accuracy: 0.7329
# Epoch 2/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5357 - accuracy: 0.7305 - val_loss: 0.5330 - val_accuracy: 0.7333
# Epoch 3/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5342 - accuracy: 0.7319 - val_loss: 0.5302 - val_accuracy: 0.7333
# Epoch 4/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5338 - accuracy: 0.7306 - val_loss: 0.5324 - val_accuracy: 0.7335
# Epoch 5/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5309 - accuracy: 0.7332 - val_loss: 0.5356 - val_accuracy: 0.7324
# Epoch 6/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5324 - accuracy: 0.7316 - val_loss: 0.5338 - val_accuracy: 0.7338
# Epoch 7/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5297 - accuracy: 0.7334 - val_loss: 0.5311 - val_accuracy: 0.7324
# Epoch 8/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5288 - accuracy: 0.7344 - val_loss: 0.5298 - val_accuracy: 0.7332
# Epoch 9/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5288 - accuracy: 0.7333 - val_loss: 0.5307 - val_accuracy: 0.7313
# Epoch 10/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5300 - accuracy: 0.7331 - val_loss: 0.5290 - val_accuracy: 0.7344
# Epoch 11/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5306 - accuracy: 0.7328 - val_loss: 0.5311 - val_accuracy: 0.7338
# Epoch 12/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5315 - accuracy: 0.7320 - val_loss: 0.5378 - val_accuracy: 0.7291
# Epoch 13/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5302 - accuracy: 0.7334 - val_loss: 0.5294 - val_accuracy: 0.7343
# Epoch 14/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5300 - accuracy: 0.7325 - val_loss: 0.5302 - val_accuracy: 0.7350
# Epoch 15/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5312 - accuracy: 0.7328 - val_loss: 0.5317 - val_accuracy: 0.7339
# Epoch 16/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5313 - accuracy: 0.7306 - val_loss: 0.5323 - val_accuracy: 0.7342
# Epoch 17/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5296 - accuracy: 0.7334 - val_loss: 0.5295 - val_accuracy: 0.7336
# Epoch 18/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5292 - accuracy: 0.7336 - val_loss: 0.5285 - val_accuracy: 0.7341
# Epoch 19/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5291 - accuracy: 0.7336 - val_loss: 0.5277 - val_accuracy: 0.7349
# Epoch 20/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5310 - accuracy: 0.7323 - val_loss: 0.5279 - val_accuracy: 0.7343
# Epoch 21/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5312 - accuracy: 0.7299 - val_loss: 0.5331 - val_accuracy: 0.7321
# Epoch 22/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5287 - accuracy: 0.7333 - val_loss: 0.5320 - val_accuracy: 0.7329
# Epoch 23/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5311 - accuracy: 0.7316 - val_loss: 0.5297 - val_accuracy: 0.7344
# Epoch 24/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5310 - accuracy: 0.7321 - val_loss: 0.5302 - val_accuracy: 0.7355
# Epoch 25/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5294 - accuracy: 0.7326 - val_loss: 0.5301 - val_accuracy: 0.7334
# Epoch 26/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5289 - accuracy: 0.7339 - val_loss: 0.5293 - val_accuracy: 0.7332
# Epoch 27/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5304 - accuracy: 0.7331 - val_loss: 0.5313 - val_accuracy: 0.7335
# Epoch 28/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5295 - accuracy: 0.7331 - val_loss: 0.5283 - val_accuracy: 0.7342
# Epoch 29/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5282 - accuracy: 0.7346 - val_loss: 0.5289 - val_accuracy: 0.7339
# Epoch 30/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5291 - accuracy: 0.7325 - val_loss: 0.5300 - val_accuracy: 0.7345
# Epoch 31/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5274 - accuracy: 0.7351 - val_loss: 0.5286 - val_accuracy: 0.7338
# Epoch 32/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5299 - accuracy: 0.7312 - val_loss: 0.5285 - val_accuracy: 0.7347
# Epoch 33/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5295 - accuracy: 0.7342 - val_loss: 0.5290 - val_accuracy: 0.7341
# Epoch 34/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5283 - accuracy: 0.7332 - val_loss: 0.5298 - val_accuracy: 0.7325
# Epoch 35/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5313 - accuracy: 0.7324 - val_loss: 0.5309 - val_accuracy: 0.7342
# Epoch 36/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5278 - accuracy: 0.7343 - val_loss: 0.5299 - val_accuracy: 0.7333
# Epoch 37/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5308 - accuracy: 0.7319 - val_loss: 0.5314 - val_accuracy: 0.7339
# Epoch 38/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5292 - accuracy: 0.7334 - val_loss: 0.5286 - val_accuracy: 0.7349
# Epoch 39/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5297 - accuracy: 0.7323 - val_loss: 0.5314 - val_accuracy: 0.7338
# Epoch 40/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5315 - accuracy: 0.7333 - val_loss: 0.5294 - val_accuracy: 0.7343
# Epoch 41/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5297 - accuracy: 0.7328 - val_loss: 0.5289 - val_accuracy: 0.7338
# Epoch 42/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5296 - accuracy: 0.7323 - val_loss: 0.5283 - val_accuracy: 0.7341
# Epoch 43/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5279 - accuracy: 0.7351 - val_loss: 0.5280 - val_accuracy: 0.7343
# Epoch 44/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5287 - accuracy: 0.7341 - val_loss: 0.5305 - val_accuracy: 0.7340
# Epoch 45/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5285 - accuracy: 0.7344 - val_loss: 0.5310 - val_accuracy: 0.7348
# Epoch 46/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5285 - accuracy: 0.7333 - val_loss: 0.5279 - val_accuracy: 0.7344
# Epoch 47/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5301 - accuracy: 0.7319 - val_loss: 0.5288 - val_accuracy: 0.7321
# Epoch 48/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5293 - accuracy: 0.7339 - val_loss: 0.5302 - val_accuracy: 0.7335
# Epoch 49/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5292 - accuracy: 0.7327 - val_loss: 0.5290 - val_accuracy: 0.7338
# Epoch 50/50
# 1458/1458 [==============================] - 2s 1ms/step - loss: 0.5281 - accuracy: 0.7350 - val_loss: 0.5297 - val_accuracy: 0.7339
# 1458/1458 [==============================] - 1s 531us/step - loss: 0.5297 - accuracy: 0.7339
# Test accuracy: 0.7339237332344055

# %%
# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)
# Out:
# 1458/1458 [==============================] - 1s 505us/step - loss: 0.5297 - accuracy: 0.7339
# Test accuracy: 0.7339237332344055
